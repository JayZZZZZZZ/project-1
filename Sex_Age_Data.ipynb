# %%
import pandas as pd
import numpy as np

# %%
#import column info
df_gender_age_info = pd.read_csv("gender_age_metadata.csv", index_col=0) 
df_gender_age_info
# Out:
#                                                             id
# GEO_ID
# NAME                                      Geographic Area Name
# DP05_0001E             Estimate!!SEX AND AGE!!Total population
# DP05_0001M      Margin of Error!!SEX AND AGE!!Total population
# DP05_0001PE             Percent!!SEX AND AGE!!Total population
# DP05_0001PM  Percent Margin of Error!!SEX AND AGE!!Total po...
# ...                                                        ...
# DP05_0088PM  Percent Margin of Error!!CITIZEN, VOTING AGE P...
# DP05_0089E   Estimate!!CITIZEN, VOTING AGE POPULATION!!Citi...
# DP05_0089M   Margin of Error!!CITIZEN, VOTING AGE POPULATIO...
# DP05_0089PE  Percent!!CITIZEN, VOTING AGE POPULATION!!Citiz...
# DP05_0089PM  Percent Margin of Error!!CITIZEN, VOTING AGE P...
#
# [357 rows x 1 columns]

# %%
#create filter for desired columns
gender_age_info_rows = ["DP05_0001E", "DP05_0003E", "DP05_0004E", "DP05_0009E", "DP05_0010E", "DP05_0011E", "DP05_0012E", "DP05_0013E", "DP05_0014E"]

# %%
#filter for desired columns
df_gender_age_info = df_gender_age_info.loc[gender_age_info_rows] 
df_gender_age_info
# Out:
#                                                            id
# GEO_ID
# DP05_0001E            Estimate!!SEX AND AGE!!Total population
# DP05_0003E    Estimate!!SEX AND AGE!!Total population!!Female
# DP05_0004E  Estimate!!SEX AND AGE!!Total population!!Sex r...
# DP05_0009E  Estimate!!SEX AND AGE!!Total population!!20 to...
# DP05_0010E  Estimate!!SEX AND AGE!!Total population!!25 to...
# DP05_0011E  Estimate!!SEX AND AGE!!Total population!!35 to...
# DP05_0012E  Estimate!!SEX AND AGE!!Total population!!45 to...
# DP05_0013E  Estimate!!SEX AND AGE!!Total population!!55 to...
# DP05_0014E  Estimate!!SEX AND AGE!!Total population!!60 to...

# %%
#clean column names
df_gender_age_info['id'] = df_gender_age_info.id.map(lambda x: x.lstrip("Estimate!!SEX AND AGE!!"))
df_gender_age_info['id'] = df_gender_age_info.id.replace("!!", ": ", regex=True)
df_gender_age_info
# Out:
#                                                            id
# GEO_ID
# DP05_0001E                                   Total population
# DP05_0003E                           Total population: Female
# DP05_0004E  Total population: Sex ratio (males per 100 fem...
# DP05_0009E                   Total population: 20 to 24 years
# DP05_0010E                   Total population: 25 to 34 years
# DP05_0011E                   Total population: 35 to 44 years
# DP05_0012E                   Total population: 45 to 54 years
# DP05_0013E                   Total population: 55 to 59 years
# DP05_0014E                   Total population: 60 to 64 years

# %%
df_gender_age = pd.read_csv("gender_age_data_with_overlays.csv", index_col = 0)
df_gender_age
# Out:
#                                                                 NAME  \
# GEO_ID
# id                                              Geographic Area Name
# 1400000US36061000100       Census Tract 1, New York County, New York
# 1400000US36061000201    Census Tract 2.01, New York County, New York
# 1400000US36061000202    Census Tract 2.02, New York County, New York
# 1400000US36061000500       Census Tract 5, New York County, New York
# ...                                                              ...
# 1400000US36061030900     Census Tract 309, New York County, New York
# 1400000US36061031100     Census Tract 311, New York County, New York
# 1400000US36061031703  Census Tract 317.03, New York County, New York
# 1400000US36061031704  Census Tract 317.04, New York County, New York
# 1400000US36061031900     Census Tract 319, New York County, New York
#
#                                                    DP05_0001E  \
# GEO_ID
# ...

# %%
df_gender_age = df_gender_age.iloc[1:] 
df_gender_age
# Out:
#                                                                 NAME  \
# GEO_ID
# 1400000US36061000100       Census Tract 1, New York County, New York
# 1400000US36061000201    Census Tract 2.01, New York County, New York
# 1400000US36061000202    Census Tract 2.02, New York County, New York
# 1400000US36061000500       Census Tract 5, New York County, New York
# 1400000US36061000600       Census Tract 6, New York County, New York
# ...                                                              ...
# 1400000US36061030900     Census Tract 309, New York County, New York
# 1400000US36061031100     Census Tract 311, New York County, New York
# 1400000US36061031703  Census Tract 317.03, New York County, New York
# 1400000US36061031704  Census Tract 317.04, New York County, New York
# 1400000US36061031900     Census Tract 319, New York County, New York
#
#                      DP05_0001E DP05_0001M DP05_0001PE DP05_0001PM DP05_0002E  \
# GEO_ID
# ...
