# %%
import pandas as pd

# %%
Stations_W_Data = pd.read_pickle('Stations_W_Data.pkl')
Stations_W_Data
# Out:
#                        name             line                    geometry  \
# 0                  Astor Pl    4-6-6 Express  POINT (-73.99107 40.73005)
# 400            8th St - NYU          N-Q-R-W  POINT (-73.99251 40.73046)
# 1                  Canal St    4-6-6 Express  POINT (-74.00019 40.71880)
# 416                Canal St              R-W  POINT (-74.00183 40.71947)
# 434                Canal St              N-Q  POINT (-74.00105 40.71881)
# ..                      ...              ...                         ...
# 467                125th St  4-5-6-6 Express  POINT (-73.93759 40.80414)
# 469  34th St - Hudson Yards      7-7 Express  POINT (-74.00220 40.75545)
# 470                 72nd St                Q  POINT (-73.95836 40.76880)
# 471                 86th St                Q  POINT (-73.95177 40.77786)
# 472                 96th St                Q  POINT (-73.94707 40.78424)
#
#            GEOID                                          NAME_y  \
# ...
